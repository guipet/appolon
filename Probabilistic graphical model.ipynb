# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas
import pandas as pd
from pylab import *
from matplotlib import pyplot

# %%
#changement du dossier par défaut
import os
os.chdir("/Users/guillaume/Desktop/MVA cours/PGM/data")

# %%
#chargement des données
testA = np.asarray(pandas.read_table("testA.txt",sep=" ",header=0))
testB = np.asarray(pandas.read_table("testB.txt",sep=" ",header=0))
testC = np.asarray(pandas.read_table("testC.txt",sep=" ",header=0))
trainA = np.asarray(pandas.read_table("trainA.txt",sep=" ",header=0))
trainB = np.asarray(pandas.read_table("trainB.txt",sep=" ",header=0))
trainC = np.asarray(pandas.read_table("trainC.txt",sep=" ",header=0))

# %%
#données training
X = trainA[:,0:2]
y = trainA[:,2]

X_B = trainB[:,0:2]
y_B = trainB[:,2]

X_C = trainC[:,0:2]
y_C = trainC[:,2]

#données test
X_test_A = testA[:,0:2]
y_test_A = testA[:,2]

X_test_B = testB[:,0:2]
y_test_B = testB[:,2]

X_test_C = testC[:,0:2]
y_test_C = testC[:,2]

# %%
#fonctions utilisées
def sigmoid(x):
        return(1/(1+np.exp(-x)))

#fonction erreur
def error(y, y_pred):
    error = sum((y-y_pred)**2) / len(y)
    return(error)

# %%
#Generative model LDA

# paramètres
def LDA(X, y, X_test, y_test, s):

    #paramètre pi
    pi = mean(y)

    #mu1
    mu1 = np.dot(X.T, y) / sum(y)

    #mu0
    mu0 = np.dot(X.T, 1-y) / sum(1-y)
    
    #sigma
    A0 = np.zeros((2,2))
    A1 = np.zeros((2,2))
    for i in range(len(y)):
        if y[i]==1:
            A1 += ((X[i,:] - mu1)[:,np.newaxis].dot((X[i,:] - mu1)[:,np.newaxis].T))
        else:
            A0 += ((X[i,:] - mu0)[:,np.newaxis].dot((X[i,:] - mu0)[:,np.newaxis].T))
        
    sigma = (A0 + A1) / len(y)
    
    #prédiction
    w = np.dot(np.linalg.inv(sigma) , (mu1 - mu0))
    b = .5*(np.dot(mu0.T, np.dot(np.linalg.inv(sigma), mu0)) - np.dot(mu1.T, np.dot(np.linalg.inv(sigma), mu1))) + np.log(pi / (1-pi))
    y_pred = np.where(X_test.dot(w) + b > 0, 1, 0)
    
    #erreur
    err = error(y_test, y_pred)
    
    #plot 
    #on récupère les x en fonction de leur label
    x1 = X[np.where(y==1)[0],0:2]    
    x0 = X[np.where(y==0)[0], 0:2]
    plt.scatter(x1[:,0], x1[:,1], c="coral", label = "y = 1")
    plt.scatter(x0[:,0], x0[:,1], c="blue", label = "y = 0" )
    plt.title('LDA pour le jeu' + str(s) )
    plt.xlabel('x1')
    plt.ylabel('x2')
    
    #print de p(y=1 \ x) = 0.5
    x , o = np.meshgrid(linspace(X[:,0].min()-2, X[:,0].max()+2, 100), linspace(X[:,1].min()-2, X[:,1].max()+2, 100))
    z = b + w[0]*x + o*w[1]
    contour(x, o, z, [0])
    plt.contourf(x, o, z, 0, cmap = plt.cm.magma, alpha = 0.5)
    plt.legend()
    return([w, b], err)

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
parA, errtestA = LDA(X, y, X_test_A, y_test_A, " A ")
subplot(1,3,2)
parB, errtestB = LDA(X_B, y_B, X_test_B, y_test_B, " B ")
subplot(1,3,3)
parC, errtestC = LDA(X_C, y_C, X_test_C, y_test_C, " C ")

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
parA, errtrainA = LDA(X, y, X, y, " A ")
subplot(1,3,2)
parB, errtrainB = LDA(X_B, y_B, X_B, y_B, " B ")
subplot(1,3,3)
parC, errtrainC = LDA(X_C, y_C, X_C, y_C, " C ")

errLDA = [errtestA, errtestB, errtestC, errtrainA, errtrainB, errtrainC]

# %%
def loglike(X, y , w):
    X = np.concatenate((np.ones((X.shape[0],1)), X), axis=1)
    return np.dot(y.T, np.log(sigmoid(np.dot(X , w)))) + np.dot((1-y).T,np.log(sigmoid(-np.dot(X , w))))




def Logistic(X, y, w , X_test, y_test,  s, tol=.00001 , n =10000):
    
    Xf = np.concatenate((np.ones((X.shape[0],1)), X), axis=1)
    
    for i in range(n):
        eta = sigmoid(Xf.dot(w))
         
            
        #grad/hess wrt w
        grad_w = Xf.T.dot(y - eta)
        hess_w = -np.dot( np.dot(Xf.T , np.diagflat(eta*(1-eta))) , Xf)


        #update
        temp_w = w - np.linalg.inv(hess_w).dot(grad_w)
        
        if np.abs(loglike(X , y , w) - loglike(X , y , temp_w)) < tol:
            print(i)
            break
            
        w = temp_w
    
    
    #prédiction
    Xtilde = np.concatenate((np.ones((X_test.shape[0],1)), X_test), axis=1)
    y_pred = np.where(Xtilde.dot(w) > 0, 1, 0)
    
    #erreur
    err = error(y_test, y_pred)
    
    
    #plot
    x1 = X[np.where(y==1)[0],0:2]    
    x0 = X[np.where(y==0)[0], 0:2]
    plt.scatter(x1[:,0], x1[:,1], c="coral", label = "y = 1")
    plt.scatter(x0[:,0], x0[:,1], c="blue", label = "y = 0" )
    plt.title('Régression logistique pour le jeu' + str(s))
    plt.xlabel('x1')
    plt.ylabel('x2')

    x , o = np.meshgrid(linspace(X[:,0].min()-2, X[:,0].max()+2, 100), linspace(X[:,1].min()-2, X[:,1].max()+2, 100))
    z = w[0] + w[1]*x + o*w[2]
    contour(x, o, z, [0])
    contourf(x, o, z, 0, cmap = plt.cm.magma, alpha = 0.5)
    plt.legend()
    return(w, err)

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
wA, errtestA = Logistic(X, y, array([.01, .02, .03]), X_test_A, y_test_A, " A ")
subplot(1,3,2)
wB, errtestB = Logistic(X_B, y_B, array([.01, .02, .03]), X_test_B, y_test_B, " B ")
subplot(1,3,3)
wC, errtestC = Logistic(X_C, y_C, array([.01, .02, .03]), X_test_C, y_test_C, " C ")
# Out:
# 17
# 8
# 6

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
wA, errtrainA = Logistic(X, y, array([.01, .02, .03]), X, y, " A ")
subplot(1,3,2)
wB, errtrainB = Logistic(X_B, y_B, array([.01, .02, .03]), X_B, y_B, " B ")
subplot(1,3,3)
wC, errtrainC = Logistic(X_C, y_C, array([.01, .02, .03]), X_C, y_C, " C ")

errlog = [errtestA, errtestB, errtestC, errtrainA, errtrainB, errtrainC]
# Out:
# 17
# 8
# 6

# %%
def regbis(X, y, X_test, y_test, s):
    #on définit le x avec l'intercept
    Xtilde = np.concatenate((np.ones((len(y),1)), X), axis=1)
    
    #on trouve les poids
    poids = np.dot(np.dot(np.linalg.inv(np.dot(Xtilde.T,Xtilde)),Xtilde.T),y)
    sigma = (y-Xtilde.dot(poids)).T.dot(y - Xtilde.dot(poids)) / len(y)

    
    #prédiction
    Xbis = np.concatenate((np.ones((X_test.shape[0],1)), X_test), axis=1)
    g = np.sqrt(sigma * np.log(2 / (np.pi * sigma)))
    y_pred = np.where(np.abs(1 - Xbis.dot(poids)) < g , 1, 0)

    #erreur
    err = error(y_test, y_pred)

    #plot
    x1 = X[np.where(y==1)[0],0:2]    
    x0 = X[np.where(y==0)[0], 0:2]
    plt.scatter(x1[:,0], x1[:,1], c="coral", label = "y = 1")
    plt.scatter(x0[:,0], x0[:,1], c="blue", label = "y = 0" )
    plt.title('Régression Linéaire pour le jeu' + str(s))
    plt.xlabel('x1')
    plt.ylabel('x2')

    x , o = np.meshgrid(linspace(X[:,0].min()-2, X[:,0].max()+2, 100), linspace(X[:,1].min()-2, X[:,1].max()+2, 100))
    z = np.abs(1 - poids[0] - poids[1]*x - poids[2]*o)
    #sinon z pas abs et pas 1 - ...
    a = np.sqrt(sigma * np.log(2/(np.pi * sigma)))
    #a = 1 - ... 
    
    contour(x, o, z, [a])
    plt.legend()
    return([poids, sigma], err)

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
paramA , errtestA = regbis(X, y, X_test_A, y_test_A, " A ")
subplot(1,3,2)
paramB , errtestB = regbis(X_B, y_B, X_test_B, y_test_B, " B ")
subplot(1,3,3), 
paramC , errtestC = regbis(X_C, y_C, X_test_C, y_test_C, " C ")

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
paramA , errtrainA = regbis(X, y, X, y, " A ")
subplot(1,3,2)
paramB , errtrainB = regbis(X_B, y_B, X_B, y_B, " B ")
subplot(1,3,3), 
paramC , errtrainC = regbis(X_C, y_C, X_C, y_C, " C ")

errlin = [errtestA, errtestB, errtestC, errtrainA, errtrainB, errtrainC]

# %%
data_set =['test_A' , 'test_B' , 'test_C' , 'train_A' , 'train_B' , 'train_C']

pd.DataFrame({'Data Set': data_set , 'Erreur LDA': errLDA, 'Erreur Logistique': errlog ,'Erreur Linéaire': errlin })
# Out:
#   Data Set  Erreur LDA  Erreur Logistique  Erreur Linéaire
# 0   test_A    0.010000           0.010000         0.060000
# 1   test_B    0.045000           0.035000         0.095000
# 2   test_C    0.040000           0.046667         0.070000
# 3  train_A    0.000000           0.000000         0.040000
# 4  train_B    0.020000           0.010000         0.070000
# 5  train_C    0.026667           0.030000         0.066667

# %%
#QDA
def QDA(X, y):

    #paramètre pi
    pi = mean(y)

    #mu1
    mu1 = np.dot(X.T, y) / sum(y)

    #mu0
    mu0 = np.dot(X.T, 1-y) / sum(1-y)
    
    #sigma
    A0 = np.zeros((2,2))
    A1 = np.zeros((2,2))
    for i in range(len(y)):
        if y[i]==1:
            A1 += ((X[i,:] - mu1)[:,np.newaxis].dot((X[i,:] - mu1)[:,np.newaxis].T))
        else:
            A0 += ((X[i,:] - mu0)[:,np.newaxis].dot((X[i,:] - mu0)[:,np.newaxis].T))
        
    sigma1 =  A1 / sum(y)
    sigma0 = A0 / sum(1-y)
    print(sigma1)
    print(sigma0)
    
    #p(y=1 \ x)
    
    d = .5 * (np.linalg.inv(sigma0) - np.linalg.inv(sigma1))
    
    
    w = np.dot(np.linalg.inv(sigma1) , mu1) - np.dot(np.linalg.inv(sigma0) , mu0)
    
    
    b = .5*(np.dot(mu0.T, np.dot(np.linalg.inv(sigma0), mu0)) - np.dot(mu1.T, np.dot(np.linalg.inv(sigma1), mu1))) + np.log(pi / (1-pi)) + .5*np.log(np.linalg.det(sigma0)/np.linalg.det(sigma1))
    
    prob = sigmoid( np.dot(X , np.dot(d , X.T)) +np.dot(X,w) +b)
    
    
    #plot 
    #on récupère les x en fonction de leur label
    x1 = X[np.where(y==1)[0],0:2]    
    x0 = X[np.where(y==0)[0], 0:2]
    plt.scatter(x1[:,0], x1[:,1], c="coral", label = "y = 1")
    plt.scatter(x0[:,0], x0[:,1], c="blue", label = "y = 0" )
    plt.title('LDA pour le jeu')
    plt.xlabel('x1')
    plt.ylabel('x2')
    
    #print de p(y=1 \ x) = 0.5
    x , o = np.meshgrid(linspace(X[:,0].min()-2, X[:,0].max()+2, 100), linspace(X[:,1].min()-2, X[:,1].max()+2, 100))
    z = b + w[0]*x + o*w[1] +d[0 ,0]*(x**2) +d[0,1]*x*o + d[1,0]*x*o + d[1,1]*(o**2)
    contour(x, o, z, [0])
    contourf(x, o, z, 0, cmap = plt.cm.magma, alpha = 0.5)
    plt.legend()
    
    return([d, w, b])

# %%
figure = pyplot.figure(figsize = (20, 5))
subplot(1,3,1)
tu , ttu, tttu = QDA(X, y)
subplot(1,3,2)
ty ,tty , ttty = QDA(X_B, y_B)
subplot(1,3,3)
t ,tt, ttt = QDA(X_C, y_C)
# Out:
# [[0.7220896  0.18267769]
#  [0.18267769 0.93481714]]
# [[0.46464757 0.0989291 ]
#  [0.0989291  0.71324415]]
# [[2.36576566 1.23147744]
#  [1.23147744 2.84044647]]
# [[0.76164392 0.05352417]
#  [0.05352417 1.10741986]]
# [[1.26768817 0.45714317]
#  [0.45714317 1.44158652]]
# [[ 1.28576019 -0.43356756]
#  [-0.43356756  1.82602425]]
